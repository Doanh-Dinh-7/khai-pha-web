# %%
import os
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.common.exceptions import NoSuchElementException

# %%
# Thiết lập trình duyệt
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))

# Danh sách để lưu thông tin bài báo
articles = []

for page in range(1, 168):
    url = f"https://baodaklak.vn/khoa-hoc-cong-nghe/?paged={page}"
    driver.get(url)
    print('visit page: ', page)
    # Cào các thẻ a với class 'title1' hoặc 'title1 photo'
    elements = driver.find_elements(By.CSS_SELECTOR, "div.item.row15")

    for element in elements:
        # Lấy tiêu đề
        title_element = element.find_element(By.CSS_SELECTOR, "a.title1, a.title1.photo")
        title = title_element.text
        if(title == ""):
            continue
        href = title_element.get_attribute('href')

        # Lấy tóm tắt
        try:
            description_element = element.find_element(By.CSS_SELECTOR, "div.des")
            description = description_element.text
            if(description == ""):
                continue
        except NoSuchElementException:
            description = "Không có tóm tắt"

        # Lấy ngày đăng
        try:
            date_element = element.find_element(By.CSS_SELECTOR, "div.date.row10")
            date = date_element.text
            if(date == ""):
                continue
        except NoSuchElementException:
            date = "Không có ngày đăng"

        # Lưu thông tin bài báo
        articles.append({
            'title': title,
            'description': description,
            'date': date,
            'url' : url,
        })

# Đóng trình duyệt
driver.quit()

with open('Cau3.txt', 'w', encoding='utf-8') as file:
# In ra thông tin bài báo
    for article in articles:
        file.write(f'''
Tiêu đề: {article['title']}
Tóm tin: {article['description']}
Ngày giờ đăng bài: {article['date']} 
Nguồn tin: {article['url']}
-------------------------------------------------------------------
                   '''
        )
# Out:
# visit page:  1
# visit page:  2
# visit page:  3
# visit page:  4
# visit page:  5
# visit page:  6
# visit page:  7
# visit page:  8
# visit page:  9
# visit page:  10
# visit page:  11
# visit page:  12
# visit page:  13
# visit page:  14
# visit page:  15
# visit page:  16
# visit page:  17
# visit page:  18
# visit page:  19
# visit page:  20
# visit page:  21
# visit page:  22
# visit page:  23
# visit page:  24
# visit page:  25
# visit page:  26
# visit page:  27
# visit page:  28
# visit page:  29
# visit page:  30
# visit page:  31
# visit page:  32
# visit page:  33
# visit page:  34
# visit page:  35
# visit page:  36
# visit page:  37
# visit page:  38
# visit page:  39
# visit page:  40
# visit page:  41
# visit page:  42
# visit page:  43
# visit page:  44
# visit page:  45
# visit page:  46
# visit page:  47
# visit page:  48
# visit page:  49
# visit page:  50
# visit page:  51
# visit page:  52
# visit page:  53
# visit page:  54
# visit page:  55
# visit page:  56
# visit page:  57
# visit page:  58
# visit page:  59
# visit page:  60
# visit page:  61
# visit page:  62
# visit page:  63
# visit page:  64
# visit page:  65
# visit page:  66
# visit page:  67
# visit page:  68
# visit page:  69
# visit page:  70
# visit page:  71
# visit page:  72
# visit page:  73
# visit page:  74
# visit page:  75
# visit page:  76
# visit page:  77
# visit page:  78
# visit page:  79
# visit page:  80
# visit page:  81
# visit page:  82
# visit page:  83
# visit page:  84
# visit page:  85
# visit page:  86
# visit page:  87
# visit page:  88
# visit page:  89
# visit page:  90
# visit page:  91
# visit page:  92
# visit page:  93
# visit page:  94
# visit page:  95
# visit page:  96
# visit page:  97
# visit page:  98
# visit page:  99
# visit page:  100
# visit page:  101
# visit page:  102
# visit page:  103
# visit page:  104
# visit page:  105
# visit page:  106
# visit page:  107
# visit page:  108
# visit page:  109
# visit page:  110
# visit page:  111
# visit page:  112
# visit page:  113
# visit page:  114
# visit page:  115
# visit page:  116
# visit page:  117
# visit page:  118
# visit page:  119
# visit page:  120
# visit page:  121
# visit page:  122
# visit page:  123
# visit page:  124
# visit page:  125
# visit page:  126
# visit page:  127
# visit page:  128
# visit page:  129
# visit page:  130
# visit page:  131
# visit page:  132
# visit page:  133
# visit page:  134
# visit page:  135
# visit page:  136
# visit page:  137
# visit page:  138
# visit page:  139
# visit page:  140
# visit page:  141
# visit page:  142
# visit page:  143
# visit page:  144
# visit page:  145
# visit page:  146
# visit page:  147
# visit page:  148
# visit page:  149
# visit page:  150
# visit page:  151
# visit page:  152
# visit page:  153
# visit page:  154
# visit page:  155
# visit page:  156
# visit page:  157
# visit page:  158
# visit page:  159
# visit page:  160
# visit page:  161
# visit page:  162
# visit page:  163
# visit page:  164
# visit page:  165
# visit page:  166
# visit page:  167
